# %%
import numpy as np

# %%
import pandas as pd

# %%
column_names=['user_id','item_id', 'rating', 'timestamp']

# %%
df= pd.read_csv('u.data', sep='\t', names=column_names)

# %%
df.head() #movie lens data set
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
#get movie titles

# %%
movie_titles = pd.read_csv('Movie_Id_Titles')

# %%
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
#merging 2 dataframes

# %%
df=pd.merge(df, movie_titles, on='item_id')

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# %%
# %matplotlib inline

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
#add new no of ratings column to get better idea
ratings['num of ratings']=pd.DataFrame(df.groupby('title')['rating'].count())

# %%
ratings.head()
# Out:
#                              rating  num of ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %%
#sum visualizations

# %%
ratings['num of ratings'].hist(bins=70)

# %%
ratings['rating'].hist(bins=70)

# %%
#distribution between actual rating and no of ratings

# %%
sns.jointplot(x='rating', y='num of ratings', data=ratings, alpha=0.5)

# %%
#higher ratings for movie, more no of ratings are given with few outliers

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
moviemat= df.pivot_table(index='user_id', columns='title', values='rating')

# %%
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
#most values are NAN as many people didnt see all movies

# %%
ratings.sort_values('num of ratings',ascending=False).head()
# Out:
#                              rating  num of ratings
# title
# Star Wars (1977)           4.359589             584
# Contact (1997)             3.803536             509
# Fargo (1996)               4.155512             508
# Return of the Jedi (1983)  4.007890             507
# Liar Liar (1997)           3.156701             485

# %%
#pick 2 movies from top

# %%
starwars_user_ratings=moviemat['Star Wars (1977)']
liarliar_user_ratings=moviemat['Liar Liar (1997)']

# %%
starwars_user_ratings.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %%
#using corrwith to compare two dataframes

# %%
similar_to_starwars= moviemat.corrwith(starwars_user_ratings)
similar_to_starwars
# Out:
# c:\users\handa\appdata\local\programs\python\python36-32\lib\site-packages\numpy\lib\function_base.py:3159: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\users\handa\appdata\local\programs\python\python36-32\lib\site-packages\numpy\lib\function_base.py:3093: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)
# title
# 'Til There Was You (1997)                                   0.872872
# 1-900 (1994)                                               -0.645497
# 101 Dalmatians (1996)                                       0.211132
# 12 Angry Men (1957)                                         0.184289
# 187 (1997)                                                  0.027398
# 2 Days in the Valley (1996)                                 0.066654
# 20,000 Leagues Under the Sea (1954)                         0.289768
# 2001: A Space Odyssey (1968)                                0.230884
# ...

# %%
#our aim is to be find more correlated movies

# %%
similar_to_liarliar= moviemat.corrwith(liarliar_user_ratings)
# Out:
# c:\users\handa\appdata\local\programs\python\python36-32\lib\site-packages\numpy\lib\function_base.py:3159: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\users\handa\appdata\local\programs\python\python36-32\lib\site-packages\numpy\lib\function_base.py:3093: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
corr_starwars=pd.DataFrame(similar_to_starwars, columns=['Correlation'])

# %%
corr_starwars.dropna(inplace=True)

# %%
corr_starwars
# Out:
#                                                     Correlation
# title
# 'Til There Was You (1997)                              0.872872
# 1-900 (1994)                                          -0.645497
# 101 Dalmatians (1996)                                  0.211132
# 12 Angry Men (1957)                                    0.184289
# 187 (1997)                                             0.027398
# 2 Days in the Valley (1996)                            0.066654
# 20,000 Leagues Under the Sea (1954)                    0.289768
# 2001: A Space Odyssey (1968)                           0.230884
# 39 Steps, The (1935)                                   0.106453
# 8 1/2 (1963)                                          -0.142977
# 8 Heads in a Duffel Bag (1997)                        -0.577350
# 8 Seconds (1994)                                      -0.755929
# A Chef in Love (1996)                                  0.868599
# Above the Rim (1994)                                  -0.645497
# ...

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation
# title
# Hollow Reed (1996)                                          1.0
# Stripes (1981)                                              1.0
# Star Wars (1977)                                            1.0
# Man of the Year (1995)                                      1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Safe Passage (1994)                                         1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0
# Line King: Al Hirschfeld, The (1996)                        1.0
# Hurricane Streets (1998)                                    1.0

# %%
#filter out similar movies with less than 100 reviews

# %%
corr_starwars=corr_starwars.join(ratings['num of ratings'])

# %%
corr_starwars
# Out:
#                                                     Correlation  \
# title
# 'Til There Was You (1997)                              0.872872
# 1-900 (1994)                                          -0.645497
# 101 Dalmatians (1996)                                  0.211132
# 12 Angry Men (1957)                                    0.184289
# 187 (1997)                                             0.027398
# 2 Days in the Valley (1996)                            0.066654
# 20,000 Leagues Under the Sea (1954)                    0.289768
# 2001: A Space Odyssey (1968)                           0.230884
# 39 Steps, The (1935)                                   0.106453
# 8 1/2 (1963)                                          -0.142977
# 8 Heads in a Duffel Bag (1997)                        -0.577350
# 8 Seconds (1994)                                      -0.755929
# A Chef in Love (1996)                                  0.868599
# ...

# %%
#filter out movies having less than 100 ratings

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.748353
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
# Sting, The (1973)                                      0.367538
# Indiana Jones and the Last Crusade (1989)              0.350107
# Pinocchio (1940)                                       0.347868
# Frighteners, The (1996)                                0.332729
# L.A. Confidential (1997)                               0.319065
#
#                                                     num of ratings
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# ...

# %%
corr_liarliar=pd.DataFrame(similar_to_liarliar,columns=['Correlation'])

# %%
corr_liarliar
# Out:
#                                                     Correlation
# title
# 'Til There Was You (1997)                              0.118913
# 1-900 (1994)                                                NaN
# 101 Dalmatians (1996)                                  0.469765
# 12 Angry Men (1957)                                    0.066272
# 187 (1997)                                             0.175145
# 2 Days in the Valley (1996)                            0.040739
# 20,000 Leagues Under the Sea (1954)                   -0.027932
# 2001: A Space Odyssey (1968)                          -0.057864
# 3 Ninjas: High Noon At Mega Mountain (1998)                 NaN
# 39 Steps, The (1935)                                   0.400918
# 8 1/2 (1963)                                           0.178064
# 8 Heads in a Duffel Bag (1997)                              NaN
# 8 Seconds (1994)                                            NaN
# A Chef in Love (1996)                                  0.000000
# ...

# %%
corr_liarliar.dropna(inplace=True)

# %%
corr_liarliar=corr_liarliar.join(ratings['num of ratings'])

# %%
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head(10)
# Out:
#                                            Correlation  num of ratings
# title
# Liar Liar (1997)                              1.000000             485
# Batman Forever (1995)                         0.516968             114
# Mask, The (1994)                              0.484650             129
# Down Periscope (1996)                         0.472681             101
# Con Air (1997)                                0.469828             137
# Pretty Woman (1990)                           0.469790             164
# 101 Dalmatians (1996)                         0.469765             109
# Michael (1996)                                0.442022             119
# Waterworld (1995)                             0.438405             102
# Indiana Jones and the Last Crusade (1989)     0.414427             331

# %%
#play around with threshold
